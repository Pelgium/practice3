# %%
name=list('Кирилл')
print(name)
sort_name=name.copy()
sort_name=sorted(sort_name)
print(sort_name)
double_name=name+sort_name
double_name=double_name[3:]
print(double_name)
# Out:
# ['К', 'и', 'р', 'и', 'л', 'л']
# ['К', 'и', 'и', 'л', 'л', 'р']
# ['и', 'л', 'л', 'К', 'и', 'и', 'л', 'л', 'р']
