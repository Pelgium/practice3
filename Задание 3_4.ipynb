# %%
dict={}
dict[1]=10
dict['abc']='def'
dict[0]=[0,1,2]
dict[0,1]='a'
dict[1]+=5
dict['abc']*=2
dict[0].append(3)
dict[0].remove(0)
dict.pop((0,1))
print(dict)
# Out:
# {1: 15, 'abc': 'defdef', 0: [1, 2, 3]}
